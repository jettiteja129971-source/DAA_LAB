# %% [markdown]
# <a href="https://colab.research.google.com/github/jettiteja129971-source/DAA_LAB/blob/main/DAA_PRACTICAL_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def knapsack(weights, values, capacity):
    n = len(values)

    dp = [[0] * (capacity + 1) for _ in range(n + 1)]

    for i in range(1, n + 1):
        for w in range(1, capacity + 1):

            if weights[i - 1] <= w:
                dp[i][w] = max(
                    values[i - 1] + dp[i - 1][w - weights[i - 1]],
                    dp[i - 1][w]
                )
            else:
                dp[i][w] = dp[i - 1][w]

    return dp[n][capacity]


n = int(input("Enter number of items: "))

weights = list(map(int, input("Enter weights: ").split()))
values = list(map(int, input("Enter values: ").split()))

capacity = int(input("Enter knapsack capacity: "))

print("Maximum value:", knapsack(weights, values, capacity))
# Out:
# Enter number of items: 7
# Enter weights: 8
# Enter values: 9
# Enter knapsack capacity: 10
# Maximum value: 9
