# %% [markdown]
# <a href="https://colab.research.google.com/github/jettiteja129971-source/DAA_LAB/blob/main/DAA_PRACTICAL_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**PRACTICAL- 7**

# %%
n = int(input("Enter the number of coin denominations: "))

coins = []
print(f"Enter {n} coin denominations:")
for i in range(n):
    coins.append(int(input()))

amount = int(input("Enter the amount: "))

# DP array
dp = [float('inf')] * (amount + 1)

# Base case
dp[0] = 0

# Dynamic Programming
for i in range(1, amount + 1):
    for coin in coins:
        if coin <= i:
            dp[i] = min(dp[i], dp[i - coin] + 1)

# Display result
print("\nMinimum number of coins required:")

if dp[amount] == float('inf'):
    print("Change cannot be made with the given coins.")
else:
    print(dp[amount])

# Display DP table
print("\nDP Table:")
print(dp)

# Time Complexity
print("\nTime Complexity: O(amount × number of coins)")
print("Space Complexity: O(amount)")
# Out:
# Enter the number of coin denominations: 6
# Enter 6 coin denominations:
# 8
# 4
# 7
# 3
# 9
# 5
# Enter the amount: 6
#
# Minimum number of coins required:
# 2
#
# DP Table:
# [0, inf, inf, 1, 1, 1, 2]
#
# Time Complexity: O(amount × number of coins)
# Space Complexity: O(amount)
